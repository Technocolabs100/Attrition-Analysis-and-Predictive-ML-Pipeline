# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Get The Data

# %%
data = pd.read_csv('HR-Employee-Attrition.csv')

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### Data Exploration

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
print(data.duplicated().value_counts())
data.drop_duplicates(inplace=True)
print(len(data))
# Out:
# False    1470
# Name: count, dtype: int64
# 1470

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Target Variable

# %%
plt.figure(figsize=(15,5))
plt.rc("font", size=14)
sns.countplot(y='Attrition',data=data)
plt.show()

# %% [markdown]
# ##### over here we noticed that the Target coiumn is Highly Imbalanced,we need to balance the data by using some Statistical methods.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Attrition w.r.t Department
plt.figure(figsize=(12,5))
sns.countplot(x='Department', hue='Attrition', data=data, palette='hot')
plt.title("Attrition w.r.t Department")
plt.show()

# %%
# Attrition w.r.t EducationField
plt.figure(figsize=(12,5))
sns.countplot(x='EducationField', hue='Attrition', data=data, palette='hot')
plt.title("Attrition w.r.t EducationField")
plt.xticks(rotation=45)
plt.show()

# %%
# Attrition w.r.t JobRole
plt.figure(figsize=(12,5))
sns.countplot(x='JobRole', hue='Attrition', data=data, palette='hot')
plt.title("Attrition w.r.t JobRole")
plt.xticks(rotation=45)
plt.show()

# %%
# Attrition w.r.t Gender
# most male of female employees Attriate
plt.figure(figsize=(12,5))
sns.countplot(x='Gender', hue='Attrition', data=data, palette='hot')
plt.title("Attrition w.r.t Gender")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Oveservation

# %% [markdown]
# ##### 1)Employees working in R&D Department is more but employees from department or at position like sales Representative ,sales executives
# ##### leaves the job early.
# ##### 2)Males are more under attrition then Female

# %%
# Distribution of age
plt.figure(figsize=(12,5))

sns.distplot(data['Age'], hist=False)

plt.show()

# %% [markdown]
# ##### 1) Age column is very well normalized ,most of employees are age between 25 to 40

# %%
ordinal_features = ['Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction',
                    'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance',]
data[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  \
# 0          2                        2               3                4
# 1          1                        3               2                2
# 2          2                        4               2                3
# 3          4                        4               3                3
# 4          1                        1               3                2
#
#    PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# 0                  3                         1                1
# 1                  4                         4                3
# 2                  3                         2                3
# 3                  3                         3                3
# 4                  3                         4                3

# %%
# Attrition w.r.t Education
edu_map = {1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'}
plt.figure(figsize=(12,5))
sns.countplot(x=data['Education'].map(edu_map), hue='Attrition', data=data, palette='hot')
plt.title("Education W.R.T Attrition")
plt.show()

# %% [markdown]
# ##### Employees from Bachelor'S are more then Master's background.Attrition also more w.r.t Bachelor's.

# %% [markdown]
# ### Label Encoding

# %%
# Target Variable(Attrition)
data['Attrition'] = data['Attrition'].replace({'No': 0, 'Yes':1})

# %%
# encode binary variables
data['OverTime'] = data['OverTime'].map({'No': 0, 'Yes':1})
data['Gender'] = data['Gender'].map({'Male': 0, 'Female':1})

# %%
data['Over18'] = data['Attrition'].replace({'No': 0, 'Y':1})

# %%
# encode categorical columns which are ordinal, use labelEncoding
# apply Label encoder to df_categorical
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']
label_encoders = {}
for column in encoding_cols:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column])

# %%
# look at the final data
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Machine Learning: Splitting the data into training and testing sample

# %%
X = data.drop(['Attrition'], axis=1) # Input features
y = data['Attrition'].values

# %% [markdown]
# ### Resampling

# %% [markdown]
# ##### We are going to use Over Sampling to avoid data loss.

# %%
# Resampling
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
print(Counter(y))
rus = RandomOverSampler(random_state = 42)
X_over, y_over = rus.fit_resample(X, y)
print(Counter(y_over))
# Out:
# Counter({0: 1233, 1: 237})
# Counter({1: 1233, 0: 1233})

# %%
# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size=0.2, random_state=42)

# %%
# Sanity check for the sampled data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1972, 34)
# (1972,)
# (494, 34)
# (494,)

# %% [markdown]
# ### Logistic Regression Model

# %% [markdown]
# ##### Logistic Regression is used for predicting a Category,specially the Binary categories(yes/no,0/1).

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction=logreg.predict(X_test)
cnf_matrix = confusion_matrix(y_test, prediction)
print("Accuracy Score -", accuracy_score(y_test , prediction))
# Out:
# Accuracy Score - 0.659919028340081

# %% [markdown]
# ### Confusion Matrix

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1 = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap='Blues', fmt='d')
bottom, top = ax1.get_ylim()  #
ax1.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')



ax2 = fig.add_subplot(1, 2, 2)  
y_pred_proba = logreg.predict_proba(X_test)[::, 1]
fpr, tpr, _ = roc_curve(y_test, prediction)
auc = roc_auc_score(y_test, prediction)
ax2 = plt.plot(fpr, tpr, label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### Tuning Hyperarameters

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

# Oversampling
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X_train, y_train)

# Model training
model = RandomForestClassifier(class_weight='balanced')
model.fit(X_resampled, y_resampled)

# Predictions and evaluation
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       250
#            1       1.00      1.00      1.00       244
#
#     accuracy                           1.00       494
#    macro avg       1.00      1.00      1.00       494
# weighted avg       1.00      1.00      1.00       494
#
# [[250   0]
#  [  0 244]]

# %%
# Key findings in a clear and concise format:

findings = """
Key findings from the attrition analysis:

* **High Attrition in Sales and Marketing:** Employees in sales and marketing roles, especially sales representatives and executives, are more likely to leave due to high-pressure work environments, limited work-life balance, and perceived lack of career growth opportunities.
* **Higher Attrition Among Male Employees:** Male employees exhibit a higher attrition rate, potentially influenced by workplace culture and work-life balance challenges.
* **Attrition Among Bachelor's Degree Holders and 25-40 Age Group:** Employees with Bachelor's degrees and those in the prime age group of 25-40 are more prone to attrition, suggesting issues related to job role mismatch, limited training, and inadequate compensation and benefits.
"""

print(findings)
# Out:
# Key findings from the attrition analysis:
#
# * **High Attrition in Sales and Marketing:** Employees in sales and marketing roles, especially sales representatives and executives, are more likely to leave due to high-pressure work environments, limited work-life balance, and perceived lack of career growth opportunities.
# * **Higher Attrition Among Male Employees:** Male employees exhibit a higher attrition rate, potentially influenced by workplace culture and work-life balance challenges.
# * **Attrition Among Bachelor's Degree Holders and 25-40 Age Group:** Employees with Bachelor's degrees and those in the prime age group of 25-40 are more prone to attrition, suggesting issues related to job role mismatch, limited training, and inadequate compensation and benefits.
